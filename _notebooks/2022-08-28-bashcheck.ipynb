# %% [markdown]
# # Bash prereqs
# > Using Bash to check machine software
#
# - badges: true
# - comments: true
# - categories: [jupyter]

# %%
jupyter kernelspec list

java --version

javac --version

conda --version

conda list

conda list | grep jupyter
# Out:
# Available kernels:
#   bash       /Users/xiaoa1/Library/Jupyter/kernels/bash
#   java       /Users/xiaoa1/Library/Jupyter/kernels/java
#   python3    /Users/xiaoa1/Library/Python/3.10/share/jupyter/kernels/python3
# openjdk 17.0.5 2022-10-18
# OpenJDK Runtime Environment Temurin-17.0.5+8 (build 17.0.5+8)
# OpenJDK 64-Bit Server VM Temurin-17.0.5+8 (build 17.0.5+8, mixed mode)
# javac 17.0.5
# conda 22.11.0
# # packages in environment at /Users/xiaoa1/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2022.05                  py39_0
# _ipyw_jlab_nb_ext_conf    0.1.0            py39hecd8cb5_1
# aiohttp                   3.8.3            py39h6c40b1e_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  custom                   py39_1
# anaconda-client           1.11.0           py39hecd8cb5_0
# ...
